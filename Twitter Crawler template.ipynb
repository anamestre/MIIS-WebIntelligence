# %% [markdown]
# ## 1. Install the twitter library in python

# %%
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /home/gabi/Installations/anaconda3/lib/python3.7/site-packages (3.8.0)
# Requirement already satisfied: six>=1.10.0 in /home/gabi/Installations/anaconda3/lib/python3.7/site-packages (from tweepy) (1.12.0)
# Requirement already satisfied: requests>=2.11.1 in /home/gabi/Installations/anaconda3/lib/python3.7/site-packages (from tweepy) (2.22.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/gabi/Installations/anaconda3/lib/python3.7/site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: PySocks>=1.5.7 in /home/gabi/Installations/anaconda3/lib/python3.7/site-packages (from tweepy) (1.7.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/gabi/Installations/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/gabi/Installations/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gabi/Installations/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/gabi/Installations/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/gabi/Installations/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)

# %% [markdown]
# ## 2. Install library for JSON

# %%
# !pip install simplejson
# Out:
# Collecting simplejson
#   Downloading https://files.pythonhosted.org/packages/9b/f9/34c419bd2e00071d8899b8580c0a91970271c11e0f4a4e8a628a2ddc58ea/simplejson-3.17.0-cp37-cp37m-macosx_10_14_x86_64.whl (73kB)
#      |████████████████████████████████| 81kB 889kB/s eta 0:00:01
# Installing collected packages: simplejson
# Successfully installed simplejson-3.17.0

# %% [markdown]
# ## 3. Install sentiment analysis library

# %%
# Whatever library you use
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading https://files.pythonhosted.org/packages/60/f0/1d9bfcc8ee6b83472ec571406bd0dd51c0e6330ff1a51b2d29861d389e85/textblob-0.15.3-py2.py3-none-any.whl (636kB)
#      |████████████████████████████████| 645kB 1.0MB/s eta 0:00:01
# Requirement already satisfied: nltk>=3.1 in /anaconda3/lib/python3.7/site-packages (from textblob) (3.4.5)
# Requirement already satisfied: six in /anaconda3/lib/python3.7/site-packages (from nltk>=3.1->textblob) (1.12.0)
# Installing collected packages: textblob
# Successfully installed textblob-0.15.3

# %% [markdown]
# # Streaming tweets and perform some data analysis

# %% [markdown]
# ### Setting up and running a streaming crawler

# %%
import tweepy
import simplejson as json
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy.streaming import StreamListener
from textblob import TextBlob
 
#Complete with your keys 

consumer_key = 'aCqrloIHCuvw8rX8sON8B551T'
consumer_secret = 'CkkLBIClzyC2w00oHOateou4wxJ2IberPKXWR8WpQEi0T5Gh2s'
access_token = '173960222-v34xiH0gEFqXCoVvpnh3JgMp8xwVukAX61rqazBc'
access_secret = '9ey7wPBUkPJdu2ZxaBoOUr43dmFCj2Fql1MxBCPKEoVFg'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
print("Starting code")
print(auth)
 

class MyListener(StreamListener):
    
    def __init__(self, filename, api=None):
        super(StreamListener, self).__init__()
        self.num_tweets = 0
        self.filename = filename

    def on_data(self, data):
        try:
            with open(self.filename, 'a') as f:
                #print("test")
                if json.loads(data).get('place'):
                    print(json.loads(data)['place']['country'])
                    if json.loads(data)['place']['country'].lower() in ['spain', 'españa', 'espana']:
                        f.write(data) # This will store the whole JSON data in the file, you can perform some JSON filters
                        twitter_text = json.loads(data)['text'] # You can also print your tweets here
                        print(twitter_text)
                        self.num_tweets += 1

                        # Just to limit the number of tweets collected to check the 
                        # program at the beginning, then increase the limit
                        if self.num_tweets < 100:
                            return True
                        else:
                            print('______________ END ', self.filename)
                            return False
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True

 
    def on_error(self, status):
        print('Error :', status.place)
        return False
    
twitter_stream = Stream(auth, MyListener('gobierno2.json'))
twitter_stream.filter(track=["gobierno", "elecciones"], languages=["es"]) # Add your keywords and other filters

twitter_stream = Stream(auth, MyListener('pp.json'))
twitter_stream.filter(track=["pp"], languages=["es"]) # Add your keywords and other filters

twitter_stream = Stream(auth, MyListener('psoe.json'))
twitter_stream.filter(track=["psoe"], languages=["es"]) # Add your keywords and other filters

twitter_stream = Stream(auth, MyListener('cat.json'))
twitter_stream.filter(track=["cataluña", "catalunya"], languages=["es"]) # Add your keywords and other filters

twitter_stream = Stream(auth, MyListener('vox.json'))
twitter_stream.filter(track=["vox"], languages=["es"]) # Add your keywords and other filters

twitter_stream = Stream(auth, MyListener('ciudadanos.json'))
twitter_stream.filter(track=["ciudadanos", "ciutadans"], languages=["es"]) # Add your keywords and other filters

twitter_stream = Stream(auth, MyListener('podemos.json'))
twitter_stream.filter(track=["podemos"], languages=["es"]) # Add your keywords and other filters

print('_______ End _______')
# Out:
# Starting code
# <tweepy.auth.OAuthHandler object at 0x7f82b8268cd0>
# Venezuela
# Nicaragua
# España
# Que cunda el ejemplo.
# Argentina
# Venezuela
# España
# El gobierno de Ñ debería explicar la relación de los servicios secretos con el imán de Ripoll y los atentados de la Rambla y Cambrils.
# Suecia
# Uruguay
# Suecia
# United States
# Venezuela
# Uruguay
# España
# Hemos conseguido que el sol salga gratis. M. Rajoy nos cobraba https://t.co/JE2FLYFjmd
# Chile
# España
# @Mejor_con_Vox @SuperVox3 No hay más ignorantes que nombrar? Lo peor de la sociedad está en el gobierno!
# España
# @IreneMontero Defendiendo la politización de la justicia os situais al lado de los fascistas que quieren un régimen… https://t.co/xDsHOHJXTt
# Venezuela
# España
# @AHORA LA ULTIMA GARZON COMUNISTA Y MINISTRO DEL GOBIERNO EN UNA ENTREVISTA CON ANA PASTOR DICE QUE LAS PROPIEDADES… https://t.co/4NFtTsbckP
# United States
# España
# Las asociaciones de jueces unificarán sus reclamaciones al Gobierno https://t.co/78z7RvL87n vía @ecd_
# España
# El Gobierno impulsa cursos de fomento de la igualdad en la administración pública para funcionarios https://t.co/iB27be88GN vía @ecd_
# Venezuela
# España
# Sus argumentos han sido usar la constitución (escrita tres años después de la muerte de Franco) y comparar un "gobi… https://t.co/v7qshhYa75
# España
# https://t.co/Q7o0whCRyH Otra medida que dará trabajo....
# Dominican Republic
# Colombia
# Colombia
# Suecia
# España
# QUE TIMO DE GOBIERNO CHAVISTA CONTROLAN LOS MEDIOS DE COMUNICACION LA JUSTICIA A NUESTROS HIJOS QUIEREN TAMBIEN LAS… https://t.co/l3xDZpknat
# Colombia
# Chile
# Argentina
# España
# Gobierno de @regiondemurcia: #NoAlPinParental cc @CsRegionMurcia - ¡Firma la petición! https://t.co/CEN4mhRVZt vía @change_es
# España
# La Comisión de Presidencia solo ha realizado una sesión ordinaria en seis meses, impidiendo que la oposición pregun… https://t.co/aFVwML0pc9
# Argentina
# Colombia
# Chile
# Argentina
# Chile
# Chile
# Chile
# Chile
# Venezuela
# Chile
# España
# @InesArrimadas ha anunciado que @CiudadanosCs va a presentar en todos los ayuntamientos de España con representació… https://t.co/I5RYeLKroF
# Colombia
# Argentina
# Dominican Republic
# Argentina
# Venezuela
# España
# @Jasafella Se llama: publicidad gratuita, si tú te cuelgas la medalla que en tu gobierno, los trans ya dan clases,… https://t.co/ZqF2aeHamZ
# Argentina
# Rusia
# España
# @DebatAlRojoVivo Tienen algo que decir sobre el cierre de medios de comunicación por parte del gobierno golpista de Bolivia.
# Argentina
# Ecuador
# Argentina
# España
# Minuto de silencio en la @DeleGobCataluna con la delegada del Gobierno @CunilleraTeresa y el subdelegado del Gobier… https://t.co/KAKOIOuPVQ
# España
# A #MarcosAna le llega la noticia de que Fidel Castro había propuesto al Gobierno español un canje por su libertad.… https://t.co/IY0nniPx52
# España
# El PP siguen sin enterarse de lo q queremos los votantes de derechas,el día q haya elecciones, no se de donde van a… https://t.co/YWPIbpIgF3
# Colombia
# Colombia
# Chile
# Argentina
# Chile
# Argentina
# Chile
# Dominican Republic
# Argentina
# España
# Si Vxx quería que el Pin parental fuera motivo de controversia lo han conseguido. Ahora toca la movilización de est… https://t.co/U8mT7qxLfw
# Argentina
# Argentina
# España
# #PlenoDeControl Sr. Presidente:
#
# ¿Qué previsión tiene el Gobierno en lo que se refiere a la fecha de aprobación por… https://t.co/VYpwNARpGp
# Colombia
# United States
# Argentina
# United States
# España
# Pues yo con la llegada de ellos al gobierno, más bien diría, adiós a la casta!
# #GobiernoDeEspana
# #ULTIMAHORA… https://t.co/K0tcTjI1v5
# Honduras
# Paraguay
# Argentina
# Chile
# España
# @sanchezcastejon @PSOE La culpa de tantos Ocupas. solo es de la Basura de politiquillos
# No les da VERGÜENZA..
# Tanto… https://t.co/GKXsJ1MLaY
# Uruguay
# España
# #PlenoDeControl
# Sr. Presidente:
# “¿Qué planes tiene el Gobierno respecto de las funciones que desarrolla la Oficina… https://t.co/zNd0WHhU7T
# España
# 🏛”No tienen excusas ni justificación. El Gobierno tripartito ha dejado de invertir 100.000 euros para los jóvenes d… https://t.co/BdkMEh52qN
# Ecuador
# United States
# Dominican Republic
# Argentina
# Chile
# Colombia
# España
# Mucho ánimo a todos los españoles de bien, porque con este gobierno ilegítimo y traidor que tenemos, todos los lune… https://t.co/Q3K0McztNx
# United States
# España
# Espero desde el PFE en Canarias, Que el gobierno canario siga la misma ruta que el gobierno valenciano, dirigido ha… https://t.co/T2JAXc0lV8
# Venezuela
# Chile
# España
# 🏛En el pasado #PlenoDeControl les interpelamos sobre, el hasta el día de hoy desconocido, programa de Gobierno. ¿Pu… https://t.co/xFe9TGAtlx
# España
# El día 1O. fue un día triste para España y para Cataluña. Yo quiero una Cataluña en España no una España en Cataluñ… https://t.co/Dxw2USjzr3
# España
# Esto es tremendo. Que disparate!!!
# Chile
# España
# Van más líderes sociales asesinados que días del 2020. ¿Que los asesinatos han disminuido? @WRadioColombia… https://t.co/E30I7J4Z9w
# Chile
# España
# #PlenoDeControl
# Sr. Presidente:
# “¿Ha decidido ya el Gobierno cuál va a ser el destino futuro del antiguo edifico d… https://t.co/AwBGXbNPFw
# United States
# Argentina
# México
# Colombia
# Peru
# United States
# Argentina
# España
# https://t.co/mOFShD6tf1. El nuevo Gobierno defiende la regulación de la casas de apuesta. Mientras la derecha defie… https://t.co/i377Tc15cx
# Chile
# Colombia
# Colombia
# Colombia
# España
# @agapornifeliz @PeibolSanchez2 @ignacioaguado Trifachito es mas fácil de pronunciar que trianarquistas rojos,  que… https://t.co/VbsN7LvwlJ
# España
# Comprendo tu enfado. Pero para que RENFE funcione con puntualidad, no hace falta la independencia. Hace falta que e… https://t.co/2mP075rCY5
# Dominican Republic
# Colombia
# España
# “🇪🇸 tiene un cuerpo diplomático de primerísimo nivel en formación y calidad profesional. Pero los medios y recursos… https://t.co/C9pPXUDJui
# España
# 🏛#PlenoDeControl
# Sr. Pte:
# “Tras la pasada sentencia del T.S, donde se determina que sólo los diputados de la Asamb… https://t.co/un43R6tfxR
# Venezuela
# Suecia
# Paraguay
# Uruguay
# Dinamarca
# Dominican Republic
# España
# @Desayunos_tve Este tio es tonto. El poder judicial no representa a la ciudadania. El poder judicial, vela para que… https://t.co/bNv89bC4vL
# Colombia
# Peru
# Peru
# España
# En su compromiso con el objetivo de déficit para realizar políticas sociales y económicas, ¿qué crees que haria el… https://t.co/B1mNe3UXkv
# Peru
# España
# Y este es el PP moderado y constructivo...
# Chile
# Ecuador
# Venezuela
# España
# Gobierno de @regiondemurcia: #NoAlPinParental cc @CsRegionMurcia - ¡Firma la petición! https://t.co/oU3KecpuXt vía @change_es
# Peru
# Venezuela
# Colombia
# Chile
# México
# España
# @DebatAlRojoVivo ¿ Qué tiene este gobierno que no deja indiferente a nadie?.
# España
# El Vicepresidente de la Junta @JuanMarin_Cs y @rogeliovelascop han presentado las obras de la II Fase del… https://t.co/2PWRMyRr3x
# Colombia
# España
# .@pablocasado_ y @manuelvalls exploran una plataforma constitucionalista para las elecciones catalanas
#
# https://t.co/tm5jIy1GFB
# España
# .@LopezMirasF (#PP) no descarta llegar a los tribunales tras recibir el requerimiento del Gobierno de retirar el 'p… https://t.co/Psoyna2WQF
# Dominican Republic
# Paraguay
# España
# En las próximas elecciones no te quedes callada. No vendas tu voto. Lee las propuestas de los candidatos. No seas p… https://t.co/5Mmqy8auwE
# Colombia
# España
# Me aburre tanto el discurso de Ciudadanos... Bueno como a muchos españoles en las últimas elecciones
# España
# “Tenemos un servicio de grúa peor que el de Venezuela. Desde que han entrado en el Gobierno llevan ustedes paraliza… https://t.co/J26JCWRmxw
# Peru
# Argentina
# España
# TAMBIEN se lo van aplicar a los alumnos MUSULMANES,  señores del gobierno https://t.co/hvwxqk2yro
# España
# No todo es diversión @imorenomelilla , hay otras cuestiones en materia de juventud q tmb nos preocupan a los jóvene… https://t.co/gDyoSgXcIl
# Argentina
# Colombia
# El Salvador
# Dominican Republic
# España
# La derecha no cambiando ni una coma de sus discursos desde 1934. Y la gente sigue tragándose que loa guerracivilist… https://t.co/5Dzc41CqzZ
# Colombia
# España
# @PSOE Es mejor imponer lo que al gobierno de turno le interese, si. Imponer vuestra doctrina. Eso es lo positivo pa… https://t.co/ls8DT8MfAZ
# México
# Argentina
# Peru
# España
# La derecha no cambiando ni una coma de sus discursos desde 1934. Y la gente sigue tragándose que los guerracivilist… https://t.co/Ba1Y3uL7mD
# Dominican Republic
# Colombia
# Argentina
# España
# El 155 oiga, que me lo quitan de las manos!!!
# Colombia
# Colombia
# Colombia
# España
# Muy muy muy mal lo tiene que hacer este gobierno de coalición para no gobernar toda esta década por lo menos, visto… https://t.co/sb7mQTyp0n
# United States
# Ecuador
# España
# @HerreraenCOPE
# Todos los medios informativos democráticos deben empezar hacer campaña contra este Gobierno marxista… https://t.co/rZgcUG8mYd
# Chile
# Chile
# España
# Frente al Estado español no, frente a los partidos políticos que van y vienen y dirigen el gobierno de España como… https://t.co/CwMcZHeOZW
# Estados Unidos
# Argentina
# España
# @ExpositoCOPE
# A todos los medios informativos deben empezar hacer una campaña contra este Gobierno marxista comunis… https://t.co/bAUybRSTjx
# Colombia
# Venezuela
# Argentina
# Peru
# España
# Aló mejor se cree q toda esa Gentuza le votará si se hacen nuevas elecciones,,,,, ESPAÑA VIVA 🇪🇸 🇪🇸 🇪🇸 🇪🇸
# Brasil
# Panamá
# España
# Casado quiere concurrir con Ciudadanos y Valls a las próximas elecciones catalanas https://t.co/2j0Chi1oqr
# United States
# Uruguay
# España
# @YeannettRomero @oscar_puente_ Venga , no seas boba !!
# Este gobierno es socialdemócrata y democrático .
# Aquí no se… https://t.co/iTr7iPSPYu
# Mexique
# Chile
# España
# #PlenoDeControl
# “Algo tan básico como la transparencia ha sido pisoteada por el Gobierno tripartito. Nos consta qu… https://t.co/3rG8LhuqlH
# Colombia
# Chile
# Venezuela
# Colombia
# Spain
# Manda güevos!!!!
# Como se atreve a efectuar esas declaraciones!!!! Ella tan culta y leída!!!
# Definitivamente esta ra… https://t.co/5l51gJ38dK
# Argentina
# Ecuador
# Colombia
# United States
# Colombia
# Argentina
# España
# @YeannettRomero @oscar_puente_ Tú te tenías que haber quedado en tu país y luchar por los DDHH , pero claro te vien… https://t.co/e0cN3u0k2L
# Estados Unidos
# Ecuador
# Panamá
# Paraguay
# Chile
# Argentina
# México
# México
# España
# 🏛 Hace unos días Pedro Sánchez fue elegido Presidente del Gobierno de España. En palabras de @InesArrimadas, “Sánch… https://t.co/nrkSGPbRhL
# Estados Unidos
# Argentina
# Dominican Republic
# Argentina
# España
# ..NO sólo las emisoras públicas...SINO TAMBIÉN LAS PRIVADAS...MANIPULACIÓN PARA LA OPINIÓN SOCIAL
# Chile
# México
# Colombia
# Dominican Republic
# Uruguay
# México
# Ecuador
# Argentina
# Chile
# Argentina
# Argentina
# Dominican Republic
# España
# Muy valientes para hacerlo en Murcia por pedir la autorizacion parental para ciertos talleres y charlas.
# Eso si, en… https://t.co/3vnO29uU6x
# Argentina
# Chile
# United States
# Argentina
# Ecuador
# Colombia
# Dominican Republic
# España
# No se esperaba menos de Marhuenda.
# España
# @rennoaltocampoo Mas les vale coger el toro por los cuernos ahora que aún se puede,  de lo contrario que vayan preparando nuevas elecciones
# Colombia
# España
# PERO HAY QUE SER GILIPOLLAS.
# El Salvador
# Ecuador
# United States
# Argentina
# United States
# Chile
# España
# Qué hostia tienen todos los publicistas que se intentan apropiar de la democracia o de movimientos ciudadanos para… https://t.co/aHxNXqGFGA
# Spain
# Sí claro. Y que más ?
# Argentina
# España
# El Gobierno no descarta un 155 en Murcia por el “pin parental” vamos señora @VickyRosell no tiene usted ni un poco… https://t.co/brE0frBat4
# Argentina
# United States
# Uruguay
# España
# El Consejero ha elogiado la trayectoria y la experiencia en el área del nuevo Director de Evaluación, Sebastián Chá… https://t.co/NevdAsMt06
# Paraguay
# Colombia
# Venezuela
# Colombia
# Paraguay
# Argentina
# Chile
# Colombia
# Argentina
# Peru
# España
# Y voló
# Paraguay
# Colombia
# España
# El tiempo que estudié en Cuba, recuerdo que había que hacer cola para todo lo básico. Era escaso hasta conseguir un… https://t.co/jkTyrLWpR8
# Colombia
# Argentina
# Chile
# España
# Y pensar que hasta hace unos días nadie sabía que el Pin Parental y los niños eran igual de felices o infelices...
# España
# @naranjeittor @electo_mania @larazon_es @laSextaTV @larazon_es fue la excusa perfecta del gobierno de Rajoy , es de… https://t.co/HFa5MI3LtY
# España
# Tengo a un familiar ingresado en Son Espases hospital universitario de Mallorca,pues bien con los recortes del gobi… https://t.co/zzufBLavD4
# México
# Peru
# México
# Uruguay
# United States
# Colombia
# Colombia
# Venezuela
# Argentina
# Uruguay
# España
# El #Gobierno se viene arriba: Rosell propone aplicar el 155 a #Murcia para retirar el 'pin #parental':… https://t.co/cIBUnjZpze
# Chile
# España
# Pero tranquilos, solo los ricos usas diésel.
# España
# Ésto no lo podemos permitir, el gobierno tiene que hacerse Cargo, esta gentuza rescató bancos con nuestro dinero y… https://t.co/emSIOezyLP
# Dominican Republic
# México
# Argentina
# Colombia
# Venezuela
# Peru
# Colombia
# Colombia
# Chile
# España
# Si tan seguros estáis, Porque no sé Hacen nuevas Elecciones,,,,,       ,,,,,,, ESPAÑA VIVA 🇪🇸 🇪🇸 🇪🇸 🇪🇸
# Dominican Republic
# España
# O PICHELEIRO
#
# ¿CÓMO "PODEMOS"TENER ESTA PANDILLA DE ANORMALES EN EL GOBIERNO DE ESPAÑA?Y LO QUE TODAVÍA ES PEOR ¿QU… https://t.co/UYsEE2ZtL5
# France
# Colombia
# Colombia
# Chile
# United States
# Argentina
# Colombia
# Colombia
# Chile
# México
# Argentina
# Chile
# Ecuador
# Peru
# España
# El PNV, con el apoyo de Podemos, pide al Gobierno acercar a 210 presos de ETA sin exigirles arrepentimiento ni repu… https://t.co/12Mj5cl439
# Uruguay
# Colombia
# Argentina
# Uruguay
# España
# Los que querían desjudicializar
# Argentina
# Colombia
# España
# @jordi_canyas @Tonicanto1 @PSOE @PODEMOS Conforme pasan los días, me parece que es el peor gobierno en el momento más inoportuno.
# España
# @eugenionarbaiza Este “grupo de políticos” no son un gobierno pues simplemente no están gobernando, crispar no es g… https://t.co/dPHRzT8RYI
# Peru
# United States
# Argentina
# México
# España
# Si desacata las ordenes de Madrid, porque no?
# United States
# Spain
# Efectivamente, el nuevo gobierno de democrático tiene lo justo.
# Peru
# Chile
# Colombia
# México
# España
# @MariaV_Iberica1 @CarrascoMarimar @larazon_es Pero que esta gentuza con este desgobierno esta a salvo totalmente ,… https://t.co/JDPJCFmCXk
# United States
# Colombia
# Colombia
# Argentina
# México
# Panamá
# Spain
# Luego vendremos a quejarnos de que Vox gane 50 escaños.
# España
# @CarrascoMarimar No se puede consentir , creo que no se atrevan a tanto , estamos en Democracia y si aguantamos a e… https://t.co/AJOzvlzFv0
# España
# Voy a aplicarles yo el 155 a Roland Barthes y a Derrida.
# Colombia
# Chile
# Ecuador
# Paraguay
# Chile
# Colombia
# Colombia
# Venezuela
# Argentina
# Venezuela
# Chile
# Spain
# @expansioncom @educaciongob Cuidado @regiondemurcia @LopezMirasF que viene la ministra @CelaaIsabel del gobierno… https://t.co/u7cVeoddxs
# Dominican Republic
# España
# Que nos comen los rojos!
# México
# Venezuela
# United States
# Argentina
# Venezuela
# Colombia
# Chile
# España
# Luego se quejan de VOX, pero es que el PSOE alimenta constantemente la confrontación.
# Honduras
# España
# Miedo me da ...
# Argentina
# España
# Las obras de la segunda fase del Palacio de Congresos de Córdoba comenzarán dentro de un mes. Una clara apuesta del… https://t.co/Hd92zuGecs
# Brasil
# México
# Chile
# El Salvador
# Argentina

# %% [markdown]
# ### Store the JSON data in a CSV for analysing

# %%
import simplejson as json

# Create the CSV file
with open ("MyFile.csv", 'w', encoding ='utf-8') as csv:
    # Write the title of the columns (features) that you want to store in the CSV file
    csv.write('id,'+'created_at'+'text,'+'country'+'\n')
    
    # Copy the data from the JSON file
    with open('MyFile.json', 'r', encoding ='utf-8') as jsonfile:
        for tweet in jsonfile: 
            data = json.loads(tweet)
            
            # The int values should be converted to strings
            csv.write(str(data['id'])+',')
            csv.write(str(data['created_at'])+',') 
            csv.write((str(data['text']).replace('\n', "").replace(',', ""))+',') 
            csv.write(str(data['place']['country'])) 
            csv.write('\n')

# %% [markdown]
# ### Load the previous CSV into pandas

# %%
import pandas as pd
tweets = pd.read_csv('MyFile.csv', index_col=0, encoding='ISO-8859-1')
tweets.head(100)
# Out:
#                                                  id  \
# 1215660391851642881  Fri Jan 10 15:43:17 +0000 2020
# 1215660890508447744  Fri Jan 10 15:45:16 +0000 2020
# 1215660967301931008  Fri Jan 10 15:45:35 +0000 2020
# 1215661022469443585  Fri Jan 10 15:45:48 +0000 2020
# 1215661066690158592  Fri Jan 10 15:45:58 +0000 2020
# 1215661085262565376  Fri Jan 10 15:46:03 +0000 2020
# 1215661103625199616  Fri Jan 10 15:46:07 +0000 2020
# 1215661104258527232  Fri Jan 10 15:46:07 +0000 2020
# 1215661106691076098  Fri Jan 10 15:46:08 +0000 2020
# 1215661118611308546  Fri Jan 10 15:46:11 +0000 2020
# 1215661166740926464  Fri Jan 10 15:46:22 +0000 2020
# 1215661187901292544  Fri Jan 10 15:46:27 +0000 2020
# 1215661210747768847  Fri Jan 10 15:46:33 +0000 2020
# 1215661218322468864  Fri Jan 10 15:46:34 +0000 2020
#
#                                                         created_attext  \
# 1215660391851642881  @kathlee73732050 @bubbaprog Obama ? Sadly your...
# 1215660890508447744  @JeffreyGuterman @realDonaldTrump Guterman You...
# 1215660967301931008                                       ððð
# 1215661022469443585  @KeepinUpWithCDJ @KathyB80962699 @chefkatebrow...
# 1215661066690158592                                               Good
# 1215661085262565376  @BernieBroStar @kurtbardella @BernieSanders @r...
# 1215661103625199616  -----&gt; Heres your sign. https://t.co/6thOl0...
# 1215661104258527232  @mommamia1217 @Rosie Because he is the best pr...
# 1215661106691076098  So he even fucked up his GOP Senators support?...
# 1215661118611308546  So he attacks Iran for personal and political ...
# 1215661166740926464                            https://t.co/tiet3GQzfC
# 1215661187901292544  can yâall believe in trumpâs america we go...
# 1215661210747768847  Slow motion killings of political prisoners in...
# 1215661218322468864       @secupp Shame and hypocrisy died with Trump.
#
#                            country
# 1215660391851642881  United States
# 1215660890508447744  United States
# 1215660967301931008  United States
# 1215661022469443585  United States
# 1215661066690158592  United States
# 1215661085262565376  United States
# 1215661103625199616  United States
# 1215661104258527232  United States
# 1215661106691076098  United States
# 1215661118611308546  United States
# 1215661166740926464  United States
# 1215661187901292544  United States
# 1215661210747768847  United States
# 1215661218322468864  United States

# %% [markdown]
# ### Analysing the polarity of the tweets

# %%
...

# %% [markdown]
# ### Generating a wordcloud

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

...

# %% [markdown]
# ### Your own analysis

# %%
...
